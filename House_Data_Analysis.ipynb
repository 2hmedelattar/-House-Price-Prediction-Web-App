# %% [markdown]
# # Importing Some Libraries We Need

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import plotly
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Import Our Data

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.select_dtypes(include = 'object').describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10, 6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
useless_columns = ['Id', 'PoolQC', 'Fence', 'MiscFeature', 'FireplaceQu', 'MasVnrType', 'Alley']
df.drop(useless_columns, axis = 1, inplace = True)

# %%
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
df.shape
# Out:
# (1460, 74)

# %%
correlations = df.corr(numeric_only=True)['SalePrice'].dropna()
correlations = correlations.abs().sort_values(ascending=False)
correlations = correlations.drop('SalePrice', errors='ignore')
top_25_features = correlations.head(25)
print(top_25_features)
# Out:
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# KitchenAbvGr     0.135907
# EnclosedPorch    0.128578
# Name: SalePrice, dtype: float64

# %% [markdown]
# # EnclosedPorch Column

# %%
fig = px.scatter(df, x = 'EnclosedPorch',
                 y = 'SalePrice',
                 trendline = "ols", title = 'EnclosedPorch Distribution')
fig.show()

# %% [markdown]
# # KitchenAbvGr Column

# %%
fig = px.scatter(df, x = 'KitchenAbvGr',
                 y = 'SalePrice',
                 trendline = "ols", title = 'KitchenAbvGr Distribution')
fig.show()

# %%
def one_hot_encode_column_inplace(df, column, prefix=None, drop_first=True):
    if column not in df.columns:
        raise ValueError(f'Column "{column}" not found in DataFrame.')

    dummies = pd.get_dummies(df[column], prefix=prefix or column, drop_first=drop_first)
    df = df.drop(columns=[column]).join(dummies)
    return df

# %%
df = one_hot_encode_column_inplace(df, column='KitchenAbvGr', prefix='Kitchen', drop_first=True)

# %% [markdown]
# # BedroomAbvGr Column

# %%
fig = px.scatter(df, x = 'BedroomAbvGr',
                 y = 'SalePrice',
                 trendline = "ols", title = 'BedroomAbvGr Distribution')
fig.show()

# %%
df = one_hot_encode_column_inplace(df, column='BedroomAbvGr', prefix='Bedroom', drop_first=True)

# %% [markdown]
# # BsmtUnfSF Column

# %%
fig = px.scatter(df, x = 'BsmtUnfSF',
                 y = 'SalePrice',
                 trendline = "ols", title = 'BsmtUnfSF Distribution')
fig.show()

# %%
fig = px.histogram(df, x = 'BsmtUnfSF',marginal = 'box', nbins = 10, title = 'BsmtUnfSF Distribution')
fig.update_layout(bargap = 0.1)
fig.show()

# %%
df = remove_outliers_iqr(df, 'BsmtUnfSF')

# %% [markdown]
# # BsmtFullBath Column

# %%
fig = px.scatter(df, x = 'BsmtFullBath',
                 y = 'SalePrice',
                 trendline = "ols", title = 'BsmtFullBath Distribution')
fig.show()

# %%
df = one_hot_encode_column_inplace(df, column='BsmtFullBath', prefix='BsmtFullBath', drop_first=True)

# %% [markdown]
# # LotArea Column

# %%
fig = px.scatter(df, x = 'LotArea',
                 y = 'SalePrice',
                 trendline = "ols", title = 'LotArea Distribution')
fig.show()

# %%
df = remove_outliers_iqr(df, 'LotArea')

# %% [markdown]
# # HalfBath Column

# %%
fig = px.scatter(df, x = 'HalfBath',
                 y = 'SalePrice',
                 trendline = "ols", title = 'HalfBath Distribution')
fig.show()

# %%
df = one_hot_encode_column_inplace(df, column='HalfBath', prefix='HalfBath', drop_first=True)

# %% [markdown]
# # OpenPorchSF Column

# %%
fig = px.scatter(df, x = 'OpenPorchSF',
                 y = 'SalePrice',
                 trendline = "ols", title = 'OpenPorchSF Distribution')
fig.show()

# %%
df = remove_outliers_iqr(df, 'OpenPorchSF')

# %% [markdown]
# # 2ndFlrSF Column

# %%
fig = px.scatter(df, x = '2ndFlrSF',
                 y = 'SalePrice',
                 trendline = "ols", title = '2ndFlrSF Distribution')
fig.show()

# %%
df = remove_outliers_iqr(df, '2ndFlrSF')

# %% [markdown]
# # WoodDeckSF Column

# %%
fig = px.scatter(df, x = 'WoodDeckSF',
                 y = 'SalePrice',
                 trendline = "ols", title = 'WoodDeckSF Distribution')
fig.show()

# %%
df = remove_outliers_iqr(df, 'WoodDeckSF')

# %% [markdown]
# # LotFrontage Column

# %%
fig = px.scatter(df, x = 'LotFrontage',
                 y = 'SalePrice',
                 trendline = "ols", title = 'LotFrontage Distribution')
fig.show()

# %%
df['LotFrontage'].isna().sum()
# Out:
# np.int64(206)

# %%
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
df = remove_outliers_iqr(df, 'LotFrontage')

# %% [markdown]
# # BsmtFinSF1 Column

# %%
fig = px.scatter(df, x = 'BsmtFinSF1',
                 y = 'SalePrice',
                 trendline = "ols", title = 'BsmtFinSF1 Distribution')
fig.show()

# %%
df['BsmtFinSF1'].isna().sum()
# Out:
# np.int64(0)

# %%
df = remove_outliers_iqr(df, 'BsmtFinSF1')

# %% [markdown]
# # Fireplaces Column

# %%
fig = px.scatter(df, x = 'Fireplaces',
                 y = 'SalePrice',
                 trendline = "ols", title = 'Fireplaces Distribution')
fig.show()

# %%
df = one_hot_encode_column_inplace(df, column='Fireplaces', prefix='Fireplaces', drop_first=True)

# %% [markdown]
# # MasVnrArea Column

# %%
fig = px.scatter(df, x = 'MasVnrArea',
                 y = 'SalePrice',
                 trendline = "ols", title = 'MasVnrArea Distribution')
fig.show()

# %%
df['MasVnrArea'].isna().sum()
# Out:
# np.int64(5)

# %%
df['MasVnrArea'] = df['MasVnrArea'].fillna(df['MasVnrArea'].mean())

# %%
df = remove_outliers_iqr(df, 'MasVnrArea')

# %% [markdown]
# # GarageYrBlt Column

# %%
fig = px.scatter(df, x = 'GarageYrBlt',
                 y = 'SalePrice',
                 trendline = "ols", title = 'GarageYrBlt Distribution')
fig.show()

# %%
df['GarageYrBlt'].isna().sum()
# Out:
# np.int64(65)

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(df['GarageYrBlt'].mean())

# %%
fig = px.histogram(df, x = 'GarageYrBlt',marginal = 'box', nbins = 10, title = 'GarageYrBlt Distribution')
fig.update_layout(bargap = 0.1)
fig.show()

# %% [markdown]
# # YearRemodAdd Column

# %%
fig = px.scatter(df, x = 'YearRemodAdd',
                 y = 'SalePrice',
                 trendline = "ols", title = 'YearRemodAdd Distribution')
fig.show()

# %% [markdown]
# # YearBuilt Column

# %%
fig = px.scatter(df, x = 'YearBuilt',
                 y = 'SalePrice',
                 trendline = "ols", title = 'YearBuilt Distribution')
fig.show()

# %% [markdown]
# # TotRmsAbvGrd Column

# %%
fig = px.scatter(df, x = 'TotRmsAbvGrd',
                 y = 'SalePrice',
                 trendline = "ols", title = 'TotRmsAbvGrd Distribution')
fig.show()

# %%
df['TotRmsAbvGrd'].isna().sum()
# Out:
# np.int64(0)

# %%
df = one_hot_encode_column_inplace(df, column='TotRmsAbvGrd', prefix='TotRmsAbvGrd', drop_first=True)

# %% [markdown]
# # FullBath Column

# %%
fig = px.scatter(df, x = 'FullBath',
                 y = 'SalePrice',
                 trendline = "ols", title = 'FullBath Distribution')
fig.show()

# %%
df['FullBath'].isna().sum()
# Out:
# np.int64(0)

# %%
df = one_hot_encode_column_inplace(df, column='FullBath', prefix='FullBath', drop_first=True)

# %% [markdown]
# # 1stFlrSF Column

# %%
fig = px.scatter(df, x = '1stFlrSF',
                 y = 'SalePrice',
                 trendline = "ols", title = '1stFlrSF Distribution')
fig.show()

# %%
df['1stFlrSF'].isna().sum()
# Out:
# np.int64(0)

# %%
df = remove_outliers_iqr(df, '1stFlrSF')

# %% [markdown]
# # TotalBsmtSF Column

# %%
fig = px.scatter(df, x = 'TotalBsmtSF',
                 y = 'SalePrice',
                 trendline = "ols", title = 'TotalBsmtSF Distribution')
fig.show()

# %%
df['TotalBsmtSF'].isna().sum()
# Out:
# np.int64(0)

# %%
df = remove_outliers_iqr(df, 'TotalBsmtSF')

# %% [markdown]
# # GarageArea Column

# %%
fig = px.scatter(df, x = 'GarageArea',
                 y = 'SalePrice',
                 trendline = "ols", title = 'GarageArea Distribution')
fig.show()

# %%
df['GarageArea'].isna().sum()
# Out:
# np.int64(0)

# %%
df = remove_outliers_iqr(df, 'GarageArea')

# %% [markdown]
# # GarageCars Column

# %%
fig = px.scatter(df, x = 'GarageCars',
                 y = 'SalePrice',
                 trendline = "ols", title = 'GarageCars Distribution')
fig.show()

# %%
df = one_hot_encode_column_inplace(df, column='GarageCars', prefix='GarageCars', drop_first=True)

# %% [markdown]
# # GrLivArea Column

# %%
fig = px.scatter(df, x = 'GrLivArea',
                 y = 'SalePrice',
                 trendline = "ols", title = 'GrLivArea Distribution')
fig.show()

# %%
df = remove_outliers_iqr(df, 'GrLivArea')

# %% [markdown]
# # OverallQual Column

# %%
fig = px.scatter(df, x = 'OverallQual',
                 y = 'SalePrice',
                 trendline = "ols", title = 'OverallQual Distribution')
fig.show()

# %%
df['OverallQual'].isna().sum()
# Out:
# np.int64(0)

# %%
df = one_hot_encode_column_inplace(df, column='OverallQual', prefix='OverallQual', drop_first=True)

# %%
def rsme(targets, predictions):
    return np.sqrt(np.mean(np.square(targets - predictions)))

# %% [markdown]
# ## 📈 Model Progress Log (MSE)
#
# Tracking the performance improvement step-by-step based on feature engineering and outlier handling:
#
# 1st: 76923.6343568445
# 2nd: 75434.06063284865
# 3rd: 73826.99890038594 after BsmtUnfSF
# 4th: 72261.87908981774 BsmtUnfSF after dealing with outliers by IQR
# 5th: 67079.87262988172 after BsmtFullBath
# 6th: 66987.59366297277 after Encoding BsmtFullBath
# 7th: 65426.563809597 after LotArea
# 8th: 59580.469572998045 after LotArea after dealing with outliers by IQR
# 9th: 56708.43700156854 after HalfBath
# 10th: 56240.046635145976 after Encoding HalfBath
# 11th: 55026.0524232751 after OpenPorchSF
# 12th: 53829.9384252005 after OpenPorchSF after dealing with outliers by IQR
# 13th: 51990.91772004973 after 2ndFlrSF
# 14th: 50798.53627817735 after 2ndFlrSF after dealing with outliers by IQR
# 15th: 49885.08369894418 after WoodDeckSF
# 16th: 49623.37728229154 after WoodDeckSF after dealing with outliers by IQR
# 17th: 49137.4663007914 after LotFrontage
# 18th: 48547.26322185032 after LotFrontage after dealing with outliers by IQR
# 19th: 38211.69690745342 after BsmtFinSF1
# 20th: 36675.94936344599 after BsmtFinSF1 after dealing with outliers by IQR
# 21th: 35773.419410367984 after Fireplaces
# 22th: 35565.210415177695 after Encoding Fireplaces
# 23th: 34731.093203083714 after MasVnrArea
# 24th: 33972.12462221026 after MasVnrArea after dealing with outliers by IQR
# 23th: 31234.694116002705 after GarageYrBlt
# 24th: 29507.296903486207 after YearRemodAdd
# 25th: 28869.581668202292 after YearBuilt
# 26th: 27459.839619697213 after TotRmsAbvGrd
# 27th: 27159.56791713145 after Encoding TotRmsAbvGrd
# 28th: 26952.386522659304 after FullBath
# 29th: 26935.344030089702 after Encoding FullBath
# 30th: 24769.456582884104 after 1stFlrSF
# 31th: 24427.408166382356 after 1stFlrSF after dealing with outliers by IQR
# 32th: 24212.247156383888 after TotalBsmtSF
# 33th: 23719.206874969095 after TotalBsmtSF after dealing with outliers by IQR
# 34th: 23224.23740575525 after GarageArea
# 35th: 23209.372085918352 after GarageArea after dealing with outliers by IQR
# 36th: 23163.752176584698 after GarageCars
# 37th: 22528.187167790085 after Encoding GarageCars
# 38th: 22505.592550339577 after GrLivArea
# 39th: 22134.160480667437 after GrLivArea after dealing with outliers by IQR
# 40th: 19985.357856917322 after OverallQual
# 41th: 19056.65974615341 after encoding OverallQual

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
model = LinearRegression()

# %%
inputs = df[['Kitchen_1', 'Kitchen_2', 'Kitchen_3', 'Bedroom_1', 'Bedroom_2', 'Bedroom_3', 'Bedroom_4',
            'Bedroom_5', 'Bedroom_6', 'Bedroom_8', 'BsmtUnfSF',
            'BsmtFullBath_1', 'BsmtFullBath_2', 'BsmtFullBath_3', 'LotArea', 'HalfBath_1', 'HalfBath_2',
            'OpenPorchSF', '2ndFlrSF', 'WoodDeckSF', 'LotFrontage', 'BsmtFinSF1', 'Fireplaces_1', 'Fireplaces_2',
            'Fireplaces_3', 'MasVnrArea', 'GarageYrBlt', 'YearRemodAdd', 'YearBuilt',
            'TotRmsAbvGrd_3', 'TotRmsAbvGrd_4', 'TotRmsAbvGrd_5', 'TotRmsAbvGrd_6', 'TotRmsAbvGrd_7',
            'TotRmsAbvGrd_8', 'TotRmsAbvGrd_9', 'TotRmsAbvGrd_10', 'TotRmsAbvGrd_11', 'TotRmsAbvGrd_12',
            'TotRmsAbvGrd_14', 'FullBath_1', 'FullBath_2', 'FullBath_3', '1stFlrSF', 'TotalBsmtSF',
            'GarageArea', 'GarageCars_1', 'GarageCars_2', 'GarageCars_3', 'GarageCars_4',
            'GrLivArea', 'OverallQual_2', 'OverallQual_3', 'OverallQual_4', 'OverallQual_5',
            'OverallQual_6', 'OverallQual_7', 'OverallQual_8', 'OverallQual_9', 'OverallQual_10']]
targets = df['SalePrice']

# Very Bad Model

# model.fit(inputs, targets)

# predections = model.predict(inputs)

# rsme(targets, predections)

# %%
from sklearn.model_selection import train_test_split

# Split data (80% train, 20% test)
train_x, test_x, train_y, test_y = train_test_split(inputs, targets, test_size = 0.2, random_state = 42)

# Optional: check the shape of the splits
print('Train X shape:', train_x.shape)
print('Test X shape:', test_x.shape)
# Out:
# Train X shape: (822, 60)
# Test X shape: (206, 60)

# %%
from sklearn.metrics import mean_squared_error

model.fit(train_x, train_y)

predictions = model.predict(test_x)

# Compute RMSE
rmse = np.sqrt(mean_squared_error(test_y, predictions))
print('RMSE:', rmse)
# Out:
# RMSE: 19770.039705876712

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_x_scaled = scaler.fit_transform(train_x)
test_x_scaled = scaler.transform(test_x)

# %%
model.fit(train_x_scaled, train_y)

predictions = model.predict(test_x_scaled)

# Compute RMSE
rmse = np.sqrt(mean_squared_error(test_y, predictions))
print('RMSE:', rmse)
# Out:
# RMSE: 19650.698617375092

# %%
from sklearn.linear_model import LassoCV

lasso = LassoCV(cv=5, random_state=42)
lasso.fit(train_x_scaled, train_y)

# Get selected features (non-zero coefficients)
selected_mask = lasso.coef_ != 0
selected_features = train_x.columns[selected_mask]

print('Selected Features by Lasso:')
print(selected_features.tolist())
# Out:
# Selected Features by Lasso:
# ['Kitchen_1', 'Kitchen_2', 'Bedroom_2', 'Bedroom_4', 'Bedroom_5', 'Bedroom_6', 'BsmtFullBath_1', 'BsmtFullBath_3', 'LotArea', 'HalfBath_1', 'OpenPorchSF', '2ndFlrSF', 'WoodDeckSF', 'LotFrontage', 'BsmtFinSF1', 'Fireplaces_1', 'Fireplaces_2', 'MasVnrArea', 'YearRemodAdd', 'YearBuilt', 'TotRmsAbvGrd_6', 'TotRmsAbvGrd_8', 'FullBath_3', 'TotalBsmtSF', 'GarageArea', 'GarageCars_3', 'GarageCars_4', 'GrLivArea', 'OverallQual_2', 'OverallQual_3', 'OverallQual_4', 'OverallQual_5', 'OverallQual_7', 'OverallQual_8', 'OverallQual_9', 'OverallQual_10']

# %%
train_x_selected = train_x[selected_features]
test_x_selected = test_x[selected_features]

# Scale selected features
scaler_selected = StandardScaler()
train_x_selected_scaled = scaler_selected.fit_transform(train_x_selected)
test_x_selected_scaled = scaler_selected.transform(test_x_selected)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model2 = LinearRegression()
model2.fit(train_x_selected_scaled, train_y)

predictions = model2.predict(test_x_selected_scaled)

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(test_y, predictions))
print(f'RMSE of Linear Regression on selected features: {rmse:.4f}')
# Out:
# RMSE of Linear Regression on selected features: 19582.0983

# %%
from sklearn.metrics import r2_score
r2 = r2_score(test_y, predictions)
print(f'R² Score of Linear Regression on selected features: {r2:.4f}')
# Out:
# R² Score of Linear Regression on selected features: 0.8555

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

svr_model = SVR(kernel='rbf')  

svr_model.fit(train_x_selected_scaled, train_y)

svr_predictions = svr_model.predict(test_x_selected_scaled)

svr_rmse = np.sqrt(mean_squared_error(test_y, svr_predictions))
print(f'RMSE of SVR Model on selected features: {svr_rmse:.4f}')
# Out:
# RMSE of SVR Model on selected features: 52023.4054

# %%
import streamlit as st
import numpy as np
import pandas as pd
import joblib
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error

st.title("Price Prediction App")

uploaded_file = st.file_uploader("Upload your CSV file", type=["csv"])
if uploaded_file is not None:
    data = pd.read_csv(uploaded_file)
    st.write("Data Preview", data.head())

    columns = data.columns.tolist()
    target = st.selectbox("Select target column (price)", columns)
    features = st.multiselect("Select feature columns", [col for col in columns if col != target])

    model_choice = st.selectbox("Choose model", ["Linear Regression", "SVR"])

    if features and target:
        X = data[features].values
        y = data[target].values
        scaler = StandardScaler()
        X_scaled = scaler.fit_transform(X)

        if model_choice == "Linear Regression":
            model = LinearRegression()
        else:
            model = SVR(kernel='rbf')

        model.fit(X_scaled, y)
        preds = model.predict(X_scaled)
        rmse = np.sqrt(mean_squared_error(y, preds))
        st.metric("Training RMSE", f"{rmse:.2f}")

        st.subheader("Enter feature values for prediction")
        input_data = []
        for feat in features:
            val = st.number_input(f"{feat}", value=0.0)
            input_data.append(val)

        if st.button("Predict"):
            input_scaled = scaler.transform([input_data])
            result = model.predict(input_scaled)[0]
            st.success(f"Predicted Price: {result:.2f}")
# Out:
# 2025-08-03 03:29:59.623 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 03:29:59.777
# ...
#   command:
#
#     streamlit run /Users/ahmedelattar/Documents/Artificial Intelligence/Attar_Learning_Path/Task_1_Visualization/.venv/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-08-03 03:29:59.777 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 03:29:59.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 03:29:59.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-03 03:29:59.780 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
selected_columns = ['Kitchen_1', 'Kitchen_2', 'Bedroom_2', 'Bedroom_4', 'Bedroom_5', 'Bedroom_6', 
                    'BsmtFullBath_1', 'BsmtFullBath_3', 'LotArea', 'HalfBath_1', 'OpenPorchSF', 
                    '2ndFlrSF', 'WoodDeckSF', 'LotFrontage', 'BsmtFinSF1', 'Fireplaces_1', 
                    'Fireplaces_2', 'MasVnrArea', 'YearRemodAdd', 'YearBuilt', 'TotRmsAbvGrd_6', 
                    'TotRmsAbvGrd_8', 'FullBath_3', 'TotalBsmtSF', 'GarageArea', 'GarageCars_3', 
                    'GarageCars_4', 'GrLivArea', 'OverallQual_2', 'OverallQual_3', 'OverallQual_4', 
                    'OverallQual_5', 'OverallQual_7', 'OverallQual_8', 'OverallQual_9', 
                    'OverallQual_10', 'SalePrice']

selected_data = df[selected_columns]

selected_data.to_csv("selected_features_data.csv", index=False)
